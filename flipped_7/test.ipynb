# %%
import numpy as np

def gd_matrix_factorization(R, mask, k=10, epochs=100, alpha=0.001, tol=1e-6):
    """
    Implementazione del Gradient Descent per la Matrix Factorization
    secondo il pseudocodice fornito.

    Parametri
    ---------
    R : np.ndarray
        Matrice dei rating (dimensioni: num_users x num_items). 
        Le celle mancanti devono essere 0 (o un valore neutro), 
        mentre mask le esclude dal calcolo dell'errore.
    mask : np.ndarray
        Matrice binaria (stesse dimensioni di R) con 1 sulle entry osservate, 
        0 sulle mancanti.
    k : int
        Numero di fattori latenti.
    epochs : int
        Numero di iterazioni del gradiente.
    alpha : float
        Learning rate.
    tol : float
        Tolleranza per il criterio di convergenza sul costo (opzionale).

    Ritorna
    -------
    U : np.ndarray
        Matrice dei fattori degli utenti (dimensioni: num_users x k).
    V : np.ndarray
        Matrice dei fattori degli item (dimensioni: num_items x k).
    """

    num_users, num_items = R.shape

    # 1) Inizializzazione casuale delle matrici U e V
    U = np.random.rand(num_users, k)
    V = np.random.rand(num_items, k)

    # Funzione di costo iniziale (opzionale, per monitorare convergenza)
    prev_cost = None

    for epoch in range(epochs):
        # 2) Calcola e_ij = r_ij - u_i dot v_j per tutte le entry osservate
        #    Creiamo una matrice degli errori E della stessa dimensione di R
        E = np.zeros_like(R)

        # Popoliamo E solo per (i, j) dove mask[i, j] = 1
        for i in range(num_users):
            for j in range(num_items):
                if mask[i, j] == 1:  # (i, j) in S
                    E[i, j] = R[i, j] - np.dot(U[i, :], V[j, :])

        # 3) Aggiorna U (per ogni user i e componente q)
        for i in range(num_users):
            for q in range(k):
                # Somma su tutti gli item j osservati per l'utente i
                grad_u_iq = 0.0
                for j in range(num_items):
                    if mask[i, j] == 1:  # (i, j) in S
                        grad_u_iq += E[i, j] * V[j, q]
                U[i, q] += alpha * grad_u_iq

        # 4) Aggiorna V (per ogni item j e componente q)
        for j in range(num_items):
            for q in range(k):
                # Somma su tutti gli utenti i che hanno rating osservato per item j
                grad_v_jq = 0.0
                for i in range(num_users):
                    if mask[i, j] == 1:  # (i, j) in S
                        grad_v_jq += E[i, j] * U[i, q]
                V[j, q] += alpha * grad_v_jq

        # 5) Calcolo del costo (opzionale) e check di convergenza
        #    Il costo J = 1/2 * sum((r_ij - u_i dot v_j)^2) su (i, j) in S
        cost = 0.0
        for i in range(num_users):
            for j in range(num_items):
                if mask[i, j] == 1:
                    cost += (R[i, j] - np.dot(U[i, :], V[j, :]))**2
        cost *= 0.5

        if epoch % 10 == 0:
            print(f"Epoch {epoch}, costo: {cost:.4f}")

        # Criterio di convergenza: se la riduzione del costo è < tol
        if prev_cost is not None and abs(prev_cost - cost) < tol:
            print(f"Convergenza raggiunta all'epoca {epoch} (costo ~ {cost:.4f})")
            break
        prev_cost = cost

    return U, V


# Esempio d'uso:
if __name__ == "__main__":
    # Supponendo di avere R e mask già pronti
    # (num_users x num_items)
    # R contiene 0 sulle entry mancanti, e mask=1 su quelle osservate
    R = np.array([
        [5, 3, 0, 1],
        [4, 0, 0, 1],
        [1, 1, 0, 5],
        [0, 0, 5, 4]
    ], dtype=float)
    mask = (R != 0).astype(float)

    # Parametri
    k = 2
    epochs = 10000
    alpha = 0.0001

    U, V = gd_matrix_factorization(R, mask, k, epochs, alpha)

    # Ricostruzione della matrice
    R_hat = U.dot(V.T)
    print("\nMatrice ricostruita:\n", R_hat)
# Out:
# Epoch 0, costo: 46.4809
# Epoch 10, costo: 46.3153
# Epoch 20, costo: 46.1488
# Epoch 30, costo: 45.9815
# Epoch 40, costo: 45.8134
# Epoch 50, costo: 45.6445
# Epoch 60, costo: 45.4749
# Epoch 70, costo: 45.3044
# Epoch 80, costo: 45.1333
# Epoch 90, costo: 44.9613
# Epoch 100, costo: 44.7887
# Epoch 110, costo: 44.6153
# Epoch 120, costo: 44.4412
# Epoch 130, costo: 44.2665
# Epoch 140, costo: 44.0911
# Epoch 150, costo: 43.9150
# Epoch 160, costo: 43.7383
# Epoch 170, costo: 43.5610
# Epoch 180, costo: 43.3831
# Epoch 190, costo: 43.2047
# Epoch 200, costo: 43.0256
# Epoch 210, costo: 42.8460
# Epoch 220, costo: 42.6659
# Epoch 230, costo: 42.4853
# Epoch 240, costo: 42.3042
# Epoch 250, costo: 42.1227
# Epoch 260, costo: 41.9407
# Epoch 270, costo: 41.7583
# Epoch 280, costo: 41.5754
# Epoch 290, costo: 41.3922
# Epoch 300, costo: 41.2087
# Epoch 310, costo: 41.0247
# Epoch 320, costo: 40.8405
# Epoch 330, costo: 40.6560
# Epoch 340, costo: 40.4712
# Epoch 350, costo: 40.2861
# Epoch 360, costo: 40.1009
# Epoch 370, costo: 39.9154
# Epoch 380, costo: 39.7297
# Epoch 390, costo: 39.5439
# Epoch 400, costo: 39.3579
# Epoch 410, costo: 39.1718
# Epoch 420, costo: 38.9856
# Epoch 430, costo: 38.7994
# Epoch 440, costo: 38.6131
# Epoch 450, costo: 38.4267
# Epoch 460, costo: 38.2404
# Epoch 470, costo: 38.0541
# Epoch 480, costo: 37.8679
# Epoch 490, costo: 37.6817
# Epoch 500, costo: 37.4956
# Epoch 510, costo: 37.3096
# Epoch 520, costo: 37.1238
# Epoch 530, costo: 36.9381
# Epoch 540, costo: 36.7527
# Epoch 550, costo: 36.5674
# Epoch 560, costo: 36.3823
# Epoch 570, costo: 36.1975
# Epoch 580, costo: 36.0130
# Epoch 590, costo: 35.8288
# Epoch 600, costo: 35.6449
# Epoch 610, costo: 35.4613
# Epoch 620, costo: 35.2781
# Epoch 630, costo: 35.0953
# Epoch 640, costo: 34.9129
# Epoch 650, costo: 34.7309
# Epoch 660, costo: 34.5493
# Epoch 670, costo: 34.3683
# Epoch 680, costo: 34.1877
# Epoch 690, costo: 34.0076
# Epoch 700, costo: 33.8280
# Epoch 710, costo: 33.6490
# Epoch 720, costo: 33.4705
# Epoch 730, costo: 33.2926
# Epoch 740, costo: 33.1153
# Epoch 750, costo: 32.9386
# Epoch 760, costo: 32.7625
# Epoch 770, costo: 32.5871
# Epoch 780, costo: 32.4123
# Epoch 790, costo: 32.2383
# Epoch 800, costo: 32.0649
# Epoch 810, costo: 31.8922
# Epoch 820, costo: 31.7202
# Epoch 830, costo: 31.5490
# Epoch 840, costo: 31.3785
# Epoch 850, costo: 31.2088
# Epoch 860, costo: 31.0398
# Epoch 870, costo: 30.8716
# Epoch 880, costo: 30.7042
# Epoch 890, costo: 30.5377
# Epoch 900, costo: 30.3719
# Epoch 910, costo: 30.2070
# Epoch 920, costo: 30.0429
# Epoch 930, costo: 29.8796
# Epoch 940, costo: 29.7172
# Epoch 950, costo: 29.5557
# Epoch 960, costo: 29.3950
# Epoch 970, costo: 29.2352
# Epoch 980, costo: 29.0763
# Epoch 990, costo: 28.9183
# Epoch 1000, costo: 28.7611
# Epoch 1010, costo: 28.6049
# Epoch 1020, costo: 28.4495
# Epoch 1030, costo: 28.2951
# Epoch 1040, costo: 28.1416
# Epoch 1050, costo: 27.9890
# Epoch 1060, costo: 27.8373
# Epoch 1070, costo: 27.6865
# Epoch 1080, costo: 27.5367
# Epoch 1090, costo: 27.3877
# Epoch 1100, costo: 27.2397
# Epoch 1110, costo: 27.0926
# Epoch 1120, costo: 26.9465
# Epoch 1130, costo: 26.8012
# Epoch 1140, costo: 26.6569
# Epoch 1150, costo: 26.5135
# Epoch 1160, costo: 26.3710
# Epoch 1170, costo: 26.2295
# Epoch 1180, costo: 26.0889
# Epoch 1190, costo: 25.9491
# Epoch 1200, costo: 25.8103
# Epoch 1210, costo: 25.6724
# Epoch 1220, costo: 25.5354
# Epoch 1230, costo: 25.3994
# Epoch 1240, costo: 25.2642
# Epoch 1250, costo: 25.1299
# Epoch 1260, costo: 24.9965
# Epoch 1270, costo: 24.8640
# Epoch 1280, costo: 24.7323
# Epoch 1290, costo: 24.6016
# Epoch 1300, costo: 24.4717
# Epoch 1310, costo: 24.3427
# Epoch 1320, costo: 24.2145
# Epoch 1330, costo: 24.0872
# Epoch 1340, costo: 23.9608
# Epoch 1350, costo: 23.8352
# Epoch 1360, costo: 23.7104
# Epoch 1370, costo: 23.5864
# Epoch 1380, costo: 23.4633
# Epoch 1390, costo: 23.3410
# Epoch 1400, costo: 23.2195
# Epoch 1410, costo: 23.0988
# Epoch 1420, costo: 22.9789
# Epoch 1430, costo: 22.8598
# Epoch 1440, costo: 22.7415
# Epoch 1450, costo: 22.6239
# Epoch 1460, costo: 22.5071
# Epoch 1470, costo: 22.3911
# Epoch 1480, costo: 22.2759
# Epoch 1490, costo: 22.1613
# Epoch 1500, costo: 22.0475
# Epoch 1510, costo: 21.9345
# Epoch 1520, costo: 21.8221
# Epoch 1530, costo: 21.7105
# Epoch 1540, costo: 21.5996
# Epoch 1550, costo: 21.4894
# Epoch 1560, costo: 21.3799
# Epoch 1570, costo: 21.2710
# Epoch 1580, costo: 21.1629
# Epoch 1590, costo: 21.0554
# Epoch 1600, costo: 20.9486
# Epoch 1610, costo: 20.8424
# Epoch 1620, costo: 20.7369
# Epoch 1630, costo: 20.6321
# Epoch 1640, costo: 20.5278
# Epoch 1650, costo: 20.4242
# Epoch 1660, costo: 20.3213
# Epoch 1670, costo: 20.2189
# Epoch 1680, costo: 20.1172
# Epoch 1690, costo: 20.0160
# Epoch 1700, costo: 19.9155
# Epoch 1710, costo: 19.8155
# Epoch 1720, costo: 19.7162
# Epoch 1730, costo: 19.6174
# Epoch 1740, costo: 19.5192
# Epoch 1750, costo: 19.4215
# Epoch 1760, costo: 19.3245
# Epoch 1770, costo: 19.2279
# Epoch 1780, costo: 19.1320
# Epoch 1790, costo: 19.0365
# Epoch 1800, costo: 18.9417
# Epoch 1810, costo: 18.8473
# Epoch 1820, costo: 18.7535
# Epoch 1830, costo: 18.6602
# Epoch 1840, costo: 18.5674
# Epoch 1850, costo: 18.4752
# Epoch 1860, costo: 18.3834
# Epoch 1870, costo: 18.2922
# Epoch 1880, costo: 18.2015
# Epoch 1890, costo: 18.1113
# Epoch 1900, costo: 18.0215
# Epoch 1910, costo: 17.9323
# Epoch 1920, costo: 17.8435
# Epoch 1930, costo: 17.7553
# Epoch 1940, costo: 17.6675
# Epoch 1950, costo: 17.5802
# Epoch 1960, costo: 17.4934
# Epoch 1970, costo: 17.4070
# Epoch 1980, costo: 17.3211
# Epoch 1990, costo: 17.2357
# Epoch 2000, costo: 17.1508
# Epoch 2010, costo: 17.0663
# Epoch 2020, costo: 16.9822
# Epoch 2030, costo: 16.8987
# Epoch 2040, costo: 16.8155
# Epoch 2050, costo: 16.7329
# Epoch 2060, costo: 16.6506
# Epoch 2070, costo: 16.5689
# Epoch 2080, costo: 16.4875
# Epoch 2090, costo: 16.4066
# Epoch 2100, costo: 16.3262
# Epoch 2110, costo: 16.2462
# Epoch 2120, costo: 16.1666
# Epoch 2130, costo: 16.0875
# Epoch 2140, costo: 16.0088
# Epoch 2150, costo: 15.9305
# Epoch 2160, costo: 15.8527
# Epoch 2170, costo: 15.7753
# Epoch 2180, costo: 15.6984
# Epoch 2190, costo: 15.6218
# Epoch 2200, costo: 15.5457
# Epoch 2210, costo: 15.4700
# Epoch 2220, costo: 15.3948
# Epoch 2230, costo: 15.3200
# Epoch 2240, costo: 15.2456
# Epoch 2250, costo: 15.1716
# Epoch 2260, costo: 15.0980
# Epoch 2270, costo: 15.0249
# Epoch 2280, costo: 14.9522
# Epoch 2290, costo: 14.8799
# Epoch 2300, costo: 14.8080
# Epoch 2310, costo: 14.7365
# Epoch 2320, costo: 14.6655
# Epoch 2330, costo: 14.5949
# Epoch 2340, costo: 14.5247
# Epoch 2350, costo: 14.4549
# Epoch 2360, costo: 14.3855
# Epoch 2370, costo: 14.3165
# Epoch 2380, costo: 14.2480
# Epoch 2390, costo: 14.1799
# Epoch 2400, costo: 14.1122
# Epoch 2410, costo: 14.0449
# Epoch 2420, costo: 13.9780
# Epoch 2430, costo: 13.9115
# Epoch 2440, costo: 13.8454
# Epoch 2450, costo: 13.7798
# Epoch 2460, costo: 13.7145
# Epoch 2470, costo: 13.6497
# Epoch 2480, costo: 13.5853
# Epoch 2490, costo: 13.5212
# Epoch 2500, costo: 13.4576
# Epoch 2510, costo: 13.3944
# Epoch 2520, costo: 13.3316
# Epoch 2530, costo: 13.2692
# Epoch 2540, costo: 13.2072
# Epoch 2550, costo: 13.1457
# Epoch 2560, costo: 13.0845
# Epoch 2570, costo: 13.0237
# Epoch 2580, costo: 12.9633
# Epoch 2590, costo: 12.9034
# Epoch 2600, costo: 12.8438
# Epoch 2610, costo: 12.7846
# Epoch 2620, costo: 12.7258
# Epoch 2630, costo: 12.6674
# Epoch 2640, costo: 12.6095
# Epoch 2650, costo: 12.5519
# Epoch 2660, costo: 12.4947
# Epoch 2670, costo: 12.4379
# Epoch 2680, costo: 12.3815
# Epoch 2690, costo: 12.3254
# Epoch 2700, costo: 12.2698
# Epoch 2710, costo: 12.2146
# Epoch 2720, costo: 12.1597
# Epoch 2730, costo: 12.1052
# Epoch 2740, costo: 12.0511
# Epoch 2750, costo: 11.9974
# Epoch 2760, costo: 11.9441
# Epoch 2770, costo: 11.8911
# Epoch 2780, costo: 11.8386
# Epoch 2790, costo: 11.7864
# Epoch 2800, costo: 11.7345
# Epoch 2810, costo: 11.6831
# Epoch 2820, costo: 11.6320
# Epoch 2830, costo: 11.5813
# Epoch 2840, costo: 11.5309
# Epoch 2850, costo: 11.4810
# Epoch 2860, costo: 11.4313
# Epoch 2870, costo: 11.3821
# Epoch 2880, costo: 11.3332
# Epoch 2890, costo: 11.2846
# Epoch 2900, costo: 11.2364
# Epoch 2910, costo: 11.1886
# Epoch 2920, costo: 11.1411
# Epoch 2930, costo: 11.0940
# Epoch 2940, costo: 11.0472
# Epoch 2950, costo: 11.0007
# Epoch 2960, costo: 10.9546
# Epoch 2970, costo: 10.9088
# Epoch 2980, costo: 10.8634
# Epoch 2990, costo: 10.8183
# Epoch 3000, costo: 10.7735
# Epoch 3010, costo: 10.7291
# Epoch 3020, costo: 10.6849
# Epoch 3030, costo: 10.6411
# Epoch 3040, costo: 10.5977
# Epoch 3050, costo: 10.5545
# Epoch 3060, costo: 10.5117
# Epoch 3070, costo: 10.4692
# Epoch 3080, costo: 10.4269
# Epoch 3090, costo: 10.3850
# Epoch 3100, costo: 10.3434
# Epoch 3110, costo: 10.3021
# Epoch 3120, costo: 10.2611
# Epoch 3130, costo: 10.2204
# Epoch 3140, costo: 10.1800
# Epoch 3150, costo: 10.1399
# Epoch 3160, costo: 10.1000
# Epoch 3170, costo: 10.0605
# Epoch 3180, costo: 10.0212
# Epoch 3190, costo: 9.9822
# Epoch 3200, costo: 9.9435
# Epoch 3210, costo: 9.9050
# Epoch 3220, costo: 9.8668
# Epoch 3230, costo: 9.8289
# Epoch 3240, costo: 9.7913
# Epoch 3250, costo: 9.7539
# Epoch 3260, costo: 9.7168
# Epoch 3270, costo: 9.6799
# Epoch 3280, costo: 9.6433
# Epoch 3290, costo: 9.6069
# Epoch 3300, costo: 9.5708
# Epoch 3310, costo: 9.5349
# Epoch 3320, costo: 9.4992
# Epoch 3330, costo: 9.4638
# Epoch 3340, costo: 9.4286
# Epoch 3350, costo: 9.3937
# Epoch 3360, costo: 9.3589
# Epoch 3370, costo: 9.3244
# Epoch 3380, costo: 9.2901
# Epoch 3390, costo: 9.2561
# Epoch 3400, costo: 9.2222
# Epoch 3410, costo: 9.1886
# Epoch 3420, costo: 9.1551
# Epoch 3430, costo: 9.1219
# Epoch 3440, costo: 9.0889
# Epoch 3450, costo: 9.0560
# Epoch 3460, costo: 9.0234
# Epoch 3470, costo: 8.9909
# Epoch 3480, costo: 8.9587
# Epoch 3490, costo: 8.9266
# Epoch 3500, costo: 8.8947
# Epoch 3510, costo: 8.8630
# Epoch 3520, costo: 8.8315
# Epoch 3530, costo: 8.8001
# Epoch 3540, costo: 8.7689
# Epoch 3550, costo: 8.7379
# Epoch 3560, costo: 8.7070
# Epoch 3570, costo: 8.6763
# Epoch 3580, costo: 8.6458
# Epoch 3590, costo: 8.6154
# Epoch 3600, costo: 8.5852
# Epoch 3610, costo: 8.5551
# Epoch 3620, costo: 8.5252
# Epoch 3630, costo: 8.4954
# Epoch 3640, costo: 8.4657
# Epoch 3650, costo: 8.4362
# Epoch 3660, costo: 8.4068
# Epoch 3670, costo: 8.3776
# Epoch 3680, costo: 8.3485
# Epoch 3690, costo: 8.3195
# Epoch 3700, costo: 8.2907
# Epoch 3710, costo: 8.2619
# Epoch 3720, costo: 8.2333
# Epoch 3730, costo: 8.2048
# Epoch 3740, costo: 8.1764
# Epoch 3750, costo: 8.1482
# Epoch 3760, costo: 8.1200
# Epoch 3770, costo: 8.0919
# Epoch 3780, costo: 8.0640
# Epoch 3790, costo: 8.0361
# Epoch 3800, costo: 8.0084
# Epoch 3810, costo: 7.9807
# Epoch 3820, costo: 7.9532
# Epoch 3830, costo: 7.9257
# Epoch 3840, costo: 7.8983
# Epoch 3850, costo: 7.8710
# Epoch 3860, costo: 7.8438
# Epoch 3870, costo: 7.8167
# Epoch 3880, costo: 7.7897
# Epoch 3890, costo: 7.7627
# Epoch 3900, costo: 7.7358
# Epoch 3910, costo: 7.7090
# Epoch 3920, costo: 7.6822
# Epoch 3930, costo: 7.6556
# Epoch 3940, costo: 7.6290
# Epoch 3950, costo: 7.6024
# Epoch 3960, costo: 7.5759
# Epoch 3970, costo: 7.5495
# Epoch 3980, costo: 7.5232
# Epoch 3990, costo: 7.4969
# Epoch 4000, costo: 7.4706
# Epoch 4010, costo: 7.4444
# Epoch 4020, costo: 7.4183
# Epoch 4030, costo: 7.3922
# Epoch 4040, costo: 7.3662
# Epoch 4050, costo: 7.3402
# Epoch 4060, costo: 7.3142
# Epoch 4070, costo: 7.2883
# Epoch 4080, costo: 7.2625
# Epoch 4090, costo: 7.2367
# Epoch 4100, costo: 7.2109
# Epoch 4110, costo: 7.1851
# Epoch 4120, costo: 7.1594
# Epoch 4130, costo: 7.1337
# Epoch 4140, costo: 7.1081
# Epoch 4150, costo: 7.0825
# Epoch 4160, costo: 7.0569
# Epoch 4170, costo: 7.0313
# Epoch 4180, costo: 7.0058
# Epoch 4190, costo: 6.9803
# Epoch 4200, costo: 6.9548
# Epoch 4210, costo: 6.9294
# Epoch 4220, costo: 6.9039
# Epoch 4230, costo: 6.8785
# Epoch 4240, costo: 6.8531
# Epoch 4250, costo: 6.8277
# Epoch 4260, costo: 6.8024
# Epoch 4270, costo: 6.7770
# Epoch 4280, costo: 6.7517
# Epoch 4290, costo: 6.7264
# Epoch 4300, costo: 6.7011
# Epoch 4310, costo: 6.6758
# Epoch 4320, costo: 6.6505
# Epoch 4330, costo: 6.6253
# Epoch 4340, costo: 6.6000
# Epoch 4350, costo: 6.5748
# Epoch 4360, costo: 6.5495
# Epoch 4370, costo: 6.5243
# Epoch 4380, costo: 6.4990
# Epoch 4390, costo: 6.4738
# Epoch 4400, costo: 6.4486
# Epoch 4410, costo: 6.4234
# Epoch 4420, costo: 6.3982
# Epoch 4430, costo: 6.3730
# Epoch 4440, costo: 6.3478
# Epoch 4450, costo: 6.3226
# Epoch 4460, costo: 6.2974
# Epoch 4470, costo: 6.2721
# Epoch 4480, costo: 6.2469
# Epoch 4490, costo: 6.2217
# Epoch 4500, costo: 6.1965
# Epoch 4510, costo: 6.1713
# Epoch 4520, costo: 6.1461
# Epoch 4530, costo: 6.1209
# Epoch 4540, costo: 6.0957
# Epoch 4550, costo: 6.0705
# Epoch 4560, costo: 6.0453
# Epoch 4570, costo: 6.0200
# Epoch 4580, costo: 5.9948
# Epoch 4590, costo: 5.9696
# Epoch 4600, costo: 5.9444
# Epoch 4610, costo: 5.9191
# Epoch 4620, costo: 5.8939
# Epoch 4630, costo: 5.8686
# Epoch 4640, costo: 5.8434
# Epoch 4650, costo: 5.8181
# Epoch 4660, costo: 5.7929
# Epoch 4670, costo: 5.7676
# Epoch 4680, costo: 5.7424
# Epoch 4690, costo: 5.7171
# Epoch 4700, costo: 5.6918
# Epoch 4710, costo: 5.6665
# Epoch 4720, costo: 5.6412
# Epoch 4730, costo: 5.6160
# Epoch 4740, costo: 5.5907
# Epoch 4750, costo: 5.5654
# Epoch 4760, costo: 5.5401
# Epoch 4770, costo: 5.5148
# Epoch 4780, costo: 5.4895
# Epoch 4790, costo: 5.4641
# Epoch 4800, costo: 5.4388
# Epoch 4810, costo: 5.4135
# Epoch 4820, costo: 5.3882
# Epoch 4830, costo: 5.3629
# Epoch 4840, costo: 5.3376
# Epoch 4850, costo: 5.3122
# Epoch 4860, costo: 5.2869
# Epoch 4870, costo: 5.2616
# Epoch 4880, costo: 5.2363
# Epoch 4890, costo: 5.2109
# Epoch 4900, costo: 5.1856
# Epoch 4910, costo: 5.1603
# Epoch 4920, costo: 5.1350
# Epoch 4930, costo: 5.1097
# Epoch 4940, costo: 5.0843
# Epoch 4950, costo: 5.0590
# Epoch 4960, costo: 5.0337
# Epoch 4970, costo: 5.0084
# Epoch 4980, costo: 4.9831
# Epoch 4990, costo: 4.9578
# Epoch 5000, costo: 4.9325
# Epoch 5010, costo: 4.9073
# Epoch 5020, costo: 4.8820
# Epoch 5030, costo: 4.8567
# Epoch 5040, costo: 4.8314
# Epoch 5050, costo: 4.8062
# Epoch 5060, costo: 4.7810
# Epoch 5070, costo: 4.7557
# Epoch 5080, costo: 4.7305
# Epoch 5090, costo: 4.7053
# Epoch 5100, costo: 4.6801
# Epoch 5110, costo: 4.6549
# Epoch 5120, costo: 4.6297
# Epoch 5130, costo: 4.6046
# Epoch 5140, costo: 4.5794
# Epoch 5150, costo: 4.5543
# Epoch 5160, costo: 4.5292
# Epoch 5170, costo: 4.5041
# Epoch 5180, costo: 4.4791
# Epoch 5190, costo: 4.4540
# Epoch 5200, costo: 4.4290
# Epoch 5210, costo: 4.4040
# Epoch 5220, costo: 4.3790
# Epoch 5230, costo: 4.3540
# Epoch 5240, costo: 4.3291
# Epoch 5250, costo: 4.3041
# Epoch 5260, costo: 4.2793
# Epoch 5270, costo: 4.2544
# Epoch 5280, costo: 4.2295
# Epoch 5290, costo: 4.2047
# Epoch 5300, costo: 4.1799
# Epoch 5310, costo: 4.1552
# Epoch 5320, costo: 4.1305
# Epoch 5330, costo: 4.1058
# Epoch 5340, costo: 4.0811
# Epoch 5350, costo: 4.0565
# Epoch 5360, costo: 4.0319
# Epoch 5370, costo: 4.0073
# Epoch 5380, costo: 3.9828
# Epoch 5390, costo: 3.9583
# Epoch 5400, costo: 3.9339
# Epoch 5410, costo: 3.9094
# Epoch 5420, costo: 3.8851
# Epoch 5430, costo: 3.8607
# Epoch 5440, costo: 3.8364
# Epoch 5450, costo: 3.8122
# Epoch 5460, costo: 3.7880
# Epoch 5470, costo: 3.7638
# Epoch 5480, costo: 3.7397
# Epoch 5490, costo: 3.7156
# Epoch 5500, costo: 3.6916
# Epoch 5510, costo: 3.6676
# Epoch 5520, costo: 3.6437
# Epoch 5530, costo: 3.6198
# Epoch 5540, costo: 3.5960
# Epoch 5550, costo: 3.5722
# Epoch 5560, costo: 3.5485
# Epoch 5570, costo: 3.5248
# Epoch 5580, costo: 3.5012
# Epoch 5590, costo: 3.4776
# Epoch 5600, costo: 3.4541
# Epoch 5610, costo: 3.4307
# Epoch 5620, costo: 3.4073
# Epoch 5630, costo: 3.3840
# Epoch 5640, costo: 3.3607
# Epoch 5650, costo: 3.3375
# Epoch 5660, costo: 3.3143
# Epoch 5670, costo: 3.2912
# Epoch 5680, costo: 3.2682
# Epoch 5690, costo: 3.2452
# Epoch 5700, costo: 3.2223
# Epoch 5710, costo: 3.1995
# Epoch 5720, costo: 3.1767
# Epoch 5730, costo: 3.1540
# Epoch 5740, costo: 3.1314
# Epoch 5750, costo: 3.1088
# Epoch 5760, costo: 3.0863
# Epoch 5770, costo: 3.0639
# Epoch 5780, costo: 3.0416
# Epoch 5790, costo: 3.0193
# Epoch 5800, costo: 2.9971
# Epoch 5810, costo: 2.9750
# Epoch 5820, costo: 2.9529
# Epoch 5830, costo: 2.9309
# Epoch 5840, costo: 2.9090
# Epoch 5850, costo: 2.8872
# Epoch 5860, costo: 2.8655
# Epoch 5870, costo: 2.8438
# Epoch 5880, costo: 2.8222
# Epoch 5890, costo: 2.8007
# Epoch 5900, costo: 2.7793
# Epoch 5910, costo: 2.7579
# Epoch 5920, costo: 2.7366
# Epoch 5930, costo: 2.7155
# Epoch 5940, costo: 2.6944
# Epoch 5950, costo: 2.6734
# Epoch 5960, costo: 2.6524
# Epoch 5970, costo: 2.6316
# Epoch 5980, costo: 2.6108
# Epoch 5990, costo: 2.5902
# Epoch 6000, costo: 2.5696
# Epoch 6010, costo: 2.5491
# Epoch 6020, costo: 2.5287
# Epoch 6030, costo: 2.5084
# Epoch 6040, costo: 2.4881
# Epoch 6050, costo: 2.4680
# Epoch 6060, costo: 2.4479
# Epoch 6070, costo: 2.4280
# Epoch 6080, costo: 2.4081
# Epoch 6090, costo: 2.3884
# Epoch 6100, costo: 2.3687
# Epoch 6110, costo: 2.3491
# Epoch 6120, costo: 2.3296
# Epoch 6130, costo: 2.3102
# Epoch 6140, costo: 2.2909
# Epoch 6150, costo: 2.2717
# Epoch 6160, costo: 2.2526
# Epoch 6170, costo: 2.2336
# Epoch 6180, costo: 2.2147
# Epoch 6190, costo: 2.1959
# Epoch 6200, costo: 2.1772
# Epoch 6210, costo: 2.1586
# Epoch 6220, costo: 2.1400
# Epoch 6230, costo: 2.1216
# Epoch 6240, costo: 2.1033
# Epoch 6250, costo: 2.0851
# Epoch 6260, costo: 2.0669
# Epoch 6270, costo: 2.0489
# Epoch 6280, costo: 2.0310
# Epoch 6290, costo: 2.0132
# Epoch 6300, costo: 1.9955
# Epoch 6310, costo: 1.9778
# Epoch 6320, costo: 1.9603
# Epoch 6330, costo: 1.9429
# Epoch 6340, costo: 1.9256
# Epoch 6350, costo: 1.9084
# Epoch 6360, costo: 1.8913
# Epoch 6370, costo: 1.8743
# Epoch 6380, costo: 1.8573
# Epoch 6390, costo: 1.8405
# Epoch 6400, costo: 1.8238
# Epoch 6410, costo: 1.8073
# Epoch 6420, costo: 1.7908
# Epoch 6430, costo: 1.7744
# Epoch 6440, costo: 1.7581
# Epoch 6450, costo: 1.7419
# Epoch 6460, costo: 1.7258
# Epoch 6470, costo: 1.7099
# Epoch 6480, costo: 1.6940
# Epoch 6490, costo: 1.6782
# Epoch 6500, costo: 1.6626
# Epoch 6510, costo: 1.6470
# Epoch 6520, costo: 1.6315
# Epoch 6530, costo: 1.6162
# Epoch 6540, costo: 1.6009
# Epoch 6550, costo: 1.5858
# Epoch 6560, costo: 1.5708
# Epoch 6570, costo: 1.5558
# Epoch 6580, costo: 1.5410
# Epoch 6590, costo: 1.5263
# Epoch 6600, costo: 1.5116
# Epoch 6610, costo: 1.4971
# Epoch 6620, costo: 1.4827
# Epoch 6630, costo: 1.4684
# Epoch 6640, costo: 1.4542
# Epoch 6650, costo: 1.4401
# Epoch 6660, costo: 1.4261
# Epoch 6670, costo: 1.4122
# Epoch 6680, costo: 1.3984
# Epoch 6690, costo: 1.3847
# Epoch 6700, costo: 1.3711
# Epoch 6710, costo: 1.3576
# Epoch 6720, costo: 1.3442
# Epoch 6730, costo: 1.3309
# Epoch 6740, costo: 1.3177
# Epoch 6750, costo: 1.3046
# Epoch 6760, costo: 1.2917
# Epoch 6770, costo: 1.2788
# Epoch 6780, costo: 1.2660
# Epoch 6790, costo: 1.2533
# Epoch 6800, costo: 1.2407
# Epoch 6810, costo: 1.2283
# Epoch 6820, costo: 1.2159
# Epoch 6830, costo: 1.2036
# Epoch 6840, costo: 1.1914
# Epoch 6850, costo: 1.1793
# Epoch 6860, costo: 1.1673
# Epoch 6870, costo: 1.1554
# Epoch 6880, costo: 1.1436
# Epoch 6890, costo: 1.1320
# Epoch 6900, costo: 1.1204
# Epoch 6910, costo: 1.1089
# Epoch 6920, costo: 1.0975
# Epoch 6930, costo: 1.0861
# Epoch 6940, costo: 1.0749
# Epoch 6950, costo: 1.0638
# Epoch 6960, costo: 1.0528
# Epoch 6970, costo: 1.0419
# Epoch 6980, costo: 1.0310
# Epoch 6990, costo: 1.0203
# Epoch 7000, costo: 1.0096
# Epoch 7010, costo: 0.9991
# Epoch 7020, costo: 0.9886
# Epoch 7030, costo: 0.9782
# Epoch 7040, costo: 0.9680
# Epoch 7050, costo: 0.9578
# Epoch 7060, costo: 0.9477
# Epoch 7070, costo: 0.9377
# Epoch 7080, costo: 0.9277
# Epoch 7090, costo: 0.9179
# Epoch 7100, costo: 0.9082
# Epoch 7110, costo: 0.8985
# Epoch 7120, costo: 0.8890
# Epoch 7130, costo: 0.8795
# Epoch 7140, costo: 0.8701
# Epoch 7150, costo: 0.8608
# Epoch 7160, costo: 0.8516
# Epoch 7170, costo: 0.8424
# Epoch 7180, costo: 0.8334
# Epoch 7190, costo: 0.8244
# Epoch 7200, costo: 0.8156
# Epoch 7210, costo: 0.8068
# Epoch 7220, costo: 0.7981
# Epoch 7230, costo: 0.7894
# Epoch 7240, costo: 0.7809
# Epoch 7250, costo: 0.7724
# Epoch 7260, costo: 0.7640
# Epoch 7270, costo: 0.7557
# Epoch 7280, costo: 0.7475
# Epoch 7290, costo: 0.7394
# Epoch 7300, costo: 0.7313
# Epoch 7310, costo: 0.7233
# Epoch 7320, costo: 0.7154
# Epoch 7330, costo: 0.7076
# Epoch 7340, costo: 0.6998
# Epoch 7350, costo: 0.6921
# Epoch 7360, costo: 0.6845
# Epoch 7370, costo: 0.6770
# Epoch 7380, costo: 0.6696
# Epoch 7390, costo: 0.6622
# Epoch 7400, costo: 0.6549
# Epoch 7410, costo: 0.6476
# Epoch 7420, costo: 0.6405
# Epoch 7430, costo: 0.6334
# Epoch 7440, costo: 0.6264
# Epoch 7450, costo: 0.6194
# Epoch 7460, costo: 0.6126
# Epoch 7470, costo: 0.6058
# Epoch 7480, costo: 0.5990
# Epoch 7490, costo: 0.5924
# Epoch 7500, costo: 0.5858
# Epoch 7510, costo: 0.5792
# Epoch 7520, costo: 0.5728
# Epoch 7530, costo: 0.5664
# Epoch 7540, costo: 0.5601
# Epoch 7550, costo: 0.5538
# Epoch 7560, costo: 0.5476
# Epoch 7570, costo: 0.5415
# Epoch 7580, costo: 0.5354
# Epoch 7590, costo: 0.5294
# Epoch 7600, costo: 0.5235
# Epoch 7610, costo: 0.5176
# Epoch 7620, costo: 0.5118
# Epoch 7630, costo: 0.5060
# Epoch 7640, costo: 0.5003
# Epoch 7650, costo: 0.4947
# Epoch 7660, costo: 0.4891
# Epoch 7670, costo: 0.4836
# Epoch 7680, costo: 0.4782
# Epoch 7690, costo: 0.4728
# Epoch 7700, costo: 0.4674
# Epoch 7710, costo: 0.4622
# Epoch 7720, costo: 0.4569
# Epoch 7730, costo: 0.4518
# Epoch 7740, costo: 0.4467
# Epoch 7750, costo: 0.4416
# Epoch 7760, costo: 0.4366
# Epoch 7770, costo: 0.4317
# Epoch 7780, costo: 0.4268
# Epoch 7790, costo: 0.4219
# Epoch 7800, costo: 0.4172
# Epoch 7810, costo: 0.4124
# Epoch 7820, costo: 0.4077
# Epoch 7830, costo: 0.4031
# Epoch 7840, costo: 0.3985
# Epoch 7850, costo: 0.3940
# Epoch 7860, costo: 0.3895
# Epoch 7870, costo: 0.3851
# Epoch 7880, costo: 0.3807
# Epoch 7890, costo: 0.3764
# Epoch 7900, costo: 0.3721
# Epoch 7910, costo: 0.3679
# Epoch 7920, costo: 0.3637
# Epoch 7930, costo: 0.3596
# Epoch 7940, costo: 0.3555
# Epoch 7950, costo: 0.3514
# Epoch 7960, costo: 0.3474
# Epoch 7970, costo: 0.3435
# Epoch 7980, costo: 0.3396
# Epoch 7990, costo: 0.3357
# Epoch 8000, costo: 0.3319
# Epoch 8010, costo: 0.3281
# Epoch 8020, costo: 0.3244
# Epoch 8030, costo: 0.3207
# Epoch 8040, costo: 0.3170
# Epoch 8050, costo: 0.3134
# Epoch 8060, costo: 0.3098
# Epoch 8070, costo: 0.3063
# Epoch 8080, costo: 0.3028
# Epoch 8090, costo: 0.2994
# Epoch 8100, costo: 0.2960
# Epoch 8110, costo: 0.2926
# Epoch 8120, costo: 0.2893
# Epoch 8130, costo: 0.2860
# Epoch 8140, costo: 0.2827
# Epoch 8150, costo: 0.2795
# Epoch 8160, costo: 0.2763
# Epoch 8170, costo: 0.2732
# Epoch 8180, costo: 0.2701
# Epoch 8190, costo: 0.2670
# Epoch 8200, costo: 0.2640
# Epoch 8210, costo: 0.2610
# Epoch 8220, costo: 0.2580
# Epoch 8230, costo: 0.2551
# Epoch 8240, costo: 0.2522
# Epoch 8250, costo: 0.2493
# Epoch 8260, costo: 0.2465
# Epoch 8270, costo: 0.2437
# Epoch 8280, costo: 0.2409
# Epoch 8290, costo: 0.2382
# Epoch 8300, costo: 0.2355
# Epoch 8310, costo: 0.2328
# Epoch 8320, costo: 0.2302
# Epoch 8330, costo: 0.2276
# Epoch 8340, costo: 0.2250
# Epoch 8350, costo: 0.2224
# Epoch 8360, costo: 0.2199
# Epoch 8370, costo: 0.2174
# Epoch 8380, costo: 0.2150
# Epoch 8390, costo: 0.2126
# Epoch 8400, costo: 0.2101
# Epoch 8410, costo: 0.2078
# Epoch 8420, costo: 0.2054
# Epoch 8430, costo: 0.2031
# Epoch 8440, costo: 0.2008
# Epoch 8450, costo: 0.1986
# Epoch 8460, costo: 0.1963
# Epoch 8470, costo: 0.1941
# Epoch 8480, costo: 0.1919
# Epoch 8490, costo: 0.1898
# Epoch 8500, costo: 0.1876
# Epoch 8510, costo: 0.1855
# Epoch 8520, costo: 0.1834
# Epoch 8530, costo: 0.1814
# Epoch 8540, costo: 0.1794
# Epoch 8550, costo: 0.1773
# Epoch 8560, costo: 0.1754
# Epoch 8570, costo: 0.1734
# Epoch 8580, costo: 0.1714
# Epoch 8590, costo: 0.1695
# Epoch 8600, costo: 0.1676
# Epoch 8610, costo: 0.1658
# Epoch 8620, costo: 0.1639
# Epoch 8630, costo: 0.1621
# Epoch 8640, costo: 0.1603
# Epoch 8650, costo: 0.1585
# Epoch 8660, costo: 0.1567
# Epoch 8670, costo: 0.1550
# Epoch 8680, costo: 0.1533
# Epoch 8690, costo: 0.1516
# Epoch 8700, costo: 0.1499
# Epoch 8710, costo: 0.1482
# Epoch 8720, costo: 0.1466
# Epoch 8730, costo: 0.1450
# Epoch 8740, costo: 0.1434
# Epoch 8750, costo: 0.1418
# Epoch 8760, costo: 0.1402
# Epoch 8770, costo: 0.1387
# Epoch 8780, costo: 0.1371
# Epoch 8790, costo: 0.1356
# Epoch 8800, costo: 0.1341
# Epoch 8810, costo: 0.1326
# Epoch 8820, costo: 0.1312
# Epoch 8830, costo: 0.1297
# Epoch 8840, costo: 0.1283
# Epoch 8850, costo: 0.1269
# Epoch 8860, costo: 0.1255
# Epoch 8870, costo: 0.1241
# Epoch 8880, costo: 0.1228
# Epoch 8890, costo: 0.1214
# Epoch 8900, costo: 0.1201
# Epoch 8910, costo: 0.1188
# Epoch 8920, costo: 0.1175
# Epoch 8930, costo: 0.1162
# Epoch 8940, costo: 0.1150
# Epoch 8950, costo: 0.1137
# Epoch 8960, costo: 0.1125
# Epoch 8970, costo: 0.1113
# Epoch 8980, costo: 0.1101
# Epoch 8990, costo: 0.1089
# Epoch 9000, costo: 0.1077
# Epoch 9010, costo: 0.1065
# Epoch 9020, costo: 0.1054
# Epoch 9030, costo: 0.1042
# Epoch 9040, costo: 0.1031
# Epoch 9050, costo: 0.1020
# Epoch 9060, costo: 0.1009
# Epoch 9070, costo: 0.0998
# Epoch 9080, costo: 0.0988
# Epoch 9090, costo: 0.0977
# Epoch 9100, costo: 0.0967
# Epoch 9110, costo: 0.0956
# Epoch 9120, costo: 0.0946
# Epoch 9130, costo: 0.0936
# Epoch 9140, costo: 0.0926
# Epoch 9150, costo: 0.0916
# Epoch 9160, costo: 0.0906
# Epoch 9170, costo: 0.0897
# Epoch 9180, costo: 0.0887
# Epoch 9190, costo: 0.0878
# Epoch 9200, costo: 0.0868
# Epoch 9210, costo: 0.0859
# Epoch 9220, costo: 0.0850
# Epoch 9230, costo: 0.0841
# Epoch 9240, costo: 0.0832
# Epoch 9250, costo: 0.0823
# Epoch 9260, costo: 0.0815
# Epoch 9270, costo: 0.0806
# Epoch 9280, costo: 0.0798
# Epoch 9290, costo: 0.0789
# Epoch 9300, costo: 0.0781
# Epoch 9310, costo: 0.0773
# Epoch 9320, costo: 0.0765
# Epoch 9330, costo: 0.0757
# Epoch 9340, costo: 0.0749
# Epoch 9350, costo: 0.0741
# Epoch 9360, costo: 0.0733
# Epoch 9370, costo: 0.0726
# Epoch 9380, costo: 0.0718
# Epoch 9390, costo: 0.0711
# Epoch 9400, costo: 0.0703
# Epoch 9410, costo: 0.0696
# Epoch 9420, costo: 0.0689
# Epoch 9430, costo: 0.0682
# Epoch 9440, costo: 0.0675
# Epoch 9450, costo: 0.0668
# Epoch 9460, costo: 0.0661
# Epoch 9470, costo: 0.0654
# Epoch 9480, costo: 0.0647
# Epoch 9490, costo: 0.0641
# Epoch 9500, costo: 0.0634
# Epoch 9510, costo: 0.0628
# Epoch 9520, costo: 0.0621
# Epoch 9530, costo: 0.0615
# Epoch 9540, costo: 0.0609
# Epoch 9550, costo: 0.0602
# Epoch 9560, costo: 0.0596
# Epoch 9570, costo: 0.0590
# Epoch 9580, costo: 0.0584
# Epoch 9590, costo: 0.0578
# Epoch 9600, costo: 0.0572
# Epoch 9610, costo: 0.0567
# Epoch 9620, costo: 0.0561
# Epoch 9630, costo: 0.0555
# Epoch 9640, costo: 0.0550
# Epoch 9650, costo: 0.0544
# Epoch 9660, costo: 0.0539
# Epoch 9670, costo: 0.0533
# Epoch 9680, costo: 0.0528
# Epoch 9690, costo: 0.0523
# Epoch 9700, costo: 0.0517
# Epoch 9710, costo: 0.0512
# Epoch 9720, costo: 0.0507
# Epoch 9730, costo: 0.0502
# Epoch 9740, costo: 0.0497
# Epoch 9750, costo: 0.0492
# Epoch 9760, costo: 0.0487
# Epoch 9770, costo: 0.0482
# Epoch 9780, costo: 0.0478
# Epoch 9790, costo: 0.0473
# Epoch 9800, costo: 0.0468
# Epoch 9810, costo: 0.0463
# Epoch 9820, costo: 0.0459
# Epoch 9830, costo: 0.0454
# Epoch 9840, costo: 0.0450
# Epoch 9850, costo: 0.0445
# Epoch 9860, costo: 0.0441
# Epoch 9870, costo: 0.0437
# Epoch 9880, costo: 0.0432
# Epoch 9890, costo: 0.0428
# Epoch 9900, costo: 0.0424
# Epoch 9910, costo: 0.0420
# Epoch 9920, costo: 0.0416
# Epoch 9930, costo: 0.0412
# Epoch 9940, costo: 0.0408
# Epoch 9950, costo: 0.0404
# Epoch 9960, costo: 0.0400
# Epoch 9970, costo: 0.0396
# Epoch 9980, costo: 0.0392
# Epoch 9990, costo: 0.0388
#
# Matrice ricostruita:
#  [[5.06757907 2.96264942 3.43069521 0.92112051]
#  [3.88353152 2.30100703 2.83036038 1.11136369]
#  [1.09098211 0.98857158 3.04655958 4.8482009 ]
#  [5.01141663 3.16875048 4.96488371 4.07845361]]
# Si è verificato un arresto anomalo del Kernel durante l'esecuzione del codice nella cella attiva o in una cella precedente.
#
# Esaminare il codice nelle celle per identificare una possibile causa dell'errore.
#
# Per altre informazioni, fare clic<a href='https://aka.ms/vscodeJupyterKernelCrash'>qui</a>.
#
# Per ulteriori dettagli, visualizzare Jupyter <a href='command:jupyter.viewOutput'>log</a>.
